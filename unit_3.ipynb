# %% [markdown]
# #**Creating a Subset from Raw Data**
#
#
# ## **Overview**
# - This notebook is a guide on creating a subset of data using python
# - The finished product will provide information on children's health and education in North Carolina and Virginia.
#
#
# ## **Getting Started**
#
# 1. Download the raw data as a .csv file to your computer
# 2. Create a folder in your Google Drive and upload your data to that folder.
# 3. Mount this data from Google Drive to Colab using this code:
#
#     from google.colab import drive
#     drive.mount('/content/gdrive')
#
# **NOTE** the code in the parenthesis matches where in your Google Drive you uploaded your data to.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Importing Necessary Packages**
#
# Import panda packages as "pd" for convience when coding. For example:
#
#            pd.(something)
#  This is **NOT** necessary to load the package.
#
#
# You will also need to import the numpy package which will help panda packages to do math (use "np" as an abbreviation for convenience as well)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Create a Dataframe**
#
# Our data frame will be abbreviated to "df" and we will define it by using the "pd.read_csv" function. It should look like this:
#
#         df=pd.read_csv (file)

# %%
df=pd.read_csv('/content/gdrive/My Drive/CountyHealthData_2014-2015.csv')

# %% [markdown]
# We can now see all of our data

# %%
df
# Out:
#      State Region  Division                      County   FIPS  GEOID  \
# 0       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 1       AK   West   Pacific  Aleutians West Census Area   2016   2016
# 2       AK   West   Pacific           Anchorage Borough   2020   2020
# 3       AK   West   Pacific           Anchorage Borough   2020   2020
# 4       AK   West   Pacific          Bethel Census Area   2050   2050
# ...    ...    ...       ...                         ...    ...    ...
# 6104    WY   West  Mountain                Uinta County  56041  56041
# 6105    WY   West  Mountain             Washakie County  56043  56043
# 6106    WY   West  Mountain             Washakie County  56043  56043
# 6107    WY   West  Mountain               Weston County  56045  56045
# 6108    WY   West  Mountain               Weston County  56045  56045
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 0     Insuff Data  1/1/2014              NaN                0.122  ...
# 1     Insuff Data  1/1/2015              NaN                0.122  ...
# 2       Region 22  1/1/2014           6827.0                0.125  ...
# 3       Region 22  1/1/2015           6856.0                0.125  ...
# 4     Insuff Data  1/1/2014          13345.0                0.211  ...
# ...           ...       ...              ...                  ...  ...
# 6104  Insuff Data  1/1/2015           7436.0                0.135  ...
# 6105  Insuff Data  1/1/2014           6580.0                0.106  ...
# 6106  Insuff Data  1/1/2015           7572.0                0.106  ...
# 6107  Insuff Data  1/1/2014           5633.0                0.162  ...
# 6108  Insuff Data  1/1/2015           7819.0                0.162  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 0                       NaN             0.374               0.250
# 1                       NaN             0.314               0.176
# 2                     15.37             0.218               0.096
# 3                     17.08             0.227               0.123
# 4                       NaN             0.394               0.124
# ...                     ...               ...                 ...
# 6104                  18.66             0.192               0.090
# 6105                    NaN             0.225               0.086
# 6106                    NaN             0.226               0.101
# 6107                    NaN             0.201               0.084
# 6108                    NaN             0.189               0.092
#
#       Health care costs  Could not see doctor due to cost  \
# 0                3791.0                             0.185
# 1                4837.0                             0.185
# 2                6588.0                             0.119
# 3                6582.0                             0.119
# 4                5860.0                             0.200
# ...                 ...                               ...
# 6104             7600.0                             0.123
# 6105             8202.0                             0.099
# 6106             7940.0                             0.099
# 6107             6906.0                             0.130
# 6108             7238.0                             0.130
#
#       Other primary care providers  Median household income  \
# 0                            216.0                    69192
# 1                            254.0                    74088
# 2                            135.0                    71094
# 3                            148.0                    76362
# 4                            169.0                    41722
# ...                            ...                      ...
# 6104                          47.0                    60953
# 6105                          47.0                    49533
# 6106                          47.0                    50740
# 6107                          28.0                    53665
# 6108                          28.0                    59314
#
#       Children eligible for free lunch  Homicide rate  \
# 0                                0.127            NaN
# 1                                0.133            NaN
# 2                                0.319           6.29
# 3                                0.334           5.60
# 4                                0.668          12.77
# ...                                ...            ...
# 6104                             0.273            NaN
# 6105                             0.328            NaN
# 6106                             0.309            NaN
# 6107                             0.232            NaN
# 6108                             0.235            NaN
#
#       Inadequate social support
# 0                         0.287
# 1                           NaN
# 2                         0.160
# 3                           NaN
# 4                         0.477
# ...                         ...
# 6104                        NaN
# 6105                      0.133
# 6106                        NaN
# 6107                      0.171
# 6108                        NaN
#
# [6109 rows x 64 columns]

# %% [markdown]
# # **Exploring the data**
#
# To figure out which chunk of data you want to use, first you have to look at the size of the data and what it contains. you can do this in several ways:
#
# To see how many columns and rows there are in the data set, use the "df.shape" function

# %%
df.shape
# Out:
# (6109, 64)

# %% [markdown]
# To see how many cells there are in the dataset use the "df.size" function

# %%
df. size
# Out:
# 390976

# %% [markdown]
# To see what the columns in the data set are, use the "df.columns" function

# %%
df. columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
#        'Severe housing problems', 'Driving alone to work',
#        'Long commute - driving alone', '2011 population estimate',
#        'Population that is not proficient in English',
#        'Population living in a rural area', 'Diabetes', 'HIV prevalence rate',
#        'Premature age-adjusted mortality', 'Infant mortality',
#        'Child mortality', 'Food insecurity', 'Limited access to healthy foods',
#        'Motor vehicle crash deaths', 'Drug poisoning deaths',
#        'Uninsured adults', 'Uninsured children', 'Health care costs',
#        'Could not see doctor due to cost', 'Other primary care providers',
#        'Median household income', 'Children eligible for free lunch',
#        'Homicide rate', 'Inadequate social support'],
#       dtype='object')

# %% [markdown]
# you can also use the "df.head()" funtion to view the columns in the dataset as well. this funtion also allows you to see the firs 5 row in your data, which can be a helpful preview.

# %%
df. head()
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 3    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 4    AK   West  Pacific          Bethel Census Area  2050   2050  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
# 3  1/1/2015           6856.0                0.125  ...                  17.08
# 4  1/1/2014          13345.0                0.211  ...                    NaN
#
#    Uninsured adults  Uninsured children  Health care costs  \
# 0             0.374               0.250             3791.0
# 1             0.314               0.176             4837.0
# 2             0.218               0.096             6588.0
# 3             0.227               0.123             6582.0
# 4             0.394               0.124             5860.0
#
#    Could not see doctor due to cost  Other primary care providers  \
# 0                             0.185                         216.0
# 1                             0.185                         254.0
# 2                             0.119                         135.0
# 3                             0.119                         148.0
# 4                             0.200                         169.0
#
#    Median household income  Children eligible for free lunch  Homicide rate  \
# 0                    69192                             0.127            NaN
# 1                    74088                             0.133            NaN
# 2                    71094                             0.319           6.29
# 3                    76362                             0.334           5.60
# 4                    41722                             0.668          12.77
#
#    Inadequate social support
# 0                      0.287
# 1                        NaN
# 2                      0.160
# 3                        NaN
# 4                      0.477
#
# [5 rows x 64 columns]

# %% [markdown]
# # **Filtering the data**
#
# Since the dataset is so large, we want to narrow down specific rows and columns and we can do that by filtering our data.
#  To create our subset, we will first
#  1. define a new datatframe, named 'southren_children'
#  2. use the '.loc' function to filter out the columns that we want
#
#
# For the first step, we will use this code to creat our filtered data frame
#
#     nc_children= df[df["State"]=="NC"]

# %%
nc_children= df[df["State"]=="NC"]

# %% [markdown]
# Now, for the second step, we wlil create our subset containing only the following variables:
#
#
# *   **Teen births**
# * **High school graduaiton**
# *   **Some college**
# *   **Infant mortality**
# *  **Child mortality**
# *   **Children eligible for free lunch**
#
# Use this code to do so
#
#     nc_subset = nc_children.loc[:,["State","Teen births", 'High school graduation', 'Some college', 'Infant mortality', 'Child mortality', 'Children eligible for free lunch']]
#
# **NOTE** It's important to include the 'state' column because later on, when we merge the data, we can differentiate which state's data is which.

# %%
nc_subset = nc_children.loc[:,["State","Teen births", 'High school graduation', 'Some college', 'Infant mortality', 'Child mortality', 'Children eligible for free lunch']]

# %%
nc_subset
# Out:
#      State  Teen births  High school graduation  Some college  \
# 3243    NC         42.4                   0.763         0.578
# 3244    NC         40.3                   0.758         0.575
# 3245    NC         44.2                   0.770         0.419
# 3246    NC         42.1                   0.850         0.433
# 3247    NC         53.8                   0.825         0.464
# ...    ...          ...                     ...           ...
# 3438    NC         57.3                   0.730         0.515
# 3439    NC         48.8                   0.830         0.474
# 3440    NC         46.8                   0.820         0.492
# 3441    NC         40.2                   0.775         0.510
# 3442    NC         41.7                   0.820         0.522
#
#       Infant mortality  Child mortality  Children eligible for free lunch
# 3243               8.3             62.7                             0.444
# 3244               7.7             57.7                             0.455
# 3245               8.6             50.2                             0.417
# 3246               8.0             33.1                             0.449
# 3247               NaN              NaN                             0.523
# ...                ...              ...                               ...
# 3438              11.4             61.4                             0.556
# 3439               9.5             69.0                             0.422
# 3440               9.7             53.9                             0.455
# 3441               NaN              NaN                             0.477
# 3442               NaN             70.7                             0.469
#
# [200 rows x 7 columns]

# %% [markdown]
# Perfect! Now, we're going to do the excat same thing for Virginia.
# First, create the dataframe for Virginia by performing the same steps but replacing anywhere you see an 'nc' with 'va'. *Make sure the "VA" within the brackets are capitalized to match the case from the raw data*
#
#
# Second, create another subset for virginia by again, replacing every 'nc' in the code with 'va'.

# %%
va_children= df[df["State"]=="VA"]

# %%
va_subset = va_children.loc[:,["State","Teen births", 'High school graduation', 'Some college', 'Infant mortality', 'Child mortality', 'Children eligible for free lunch']]

# %%
va_subset
# Out:
#      State  Teen births  High school graduation  Some college  \
# 5437    VA         64.5                    0.74         0.446
# 5438    VA         59.5                    0.80         0.420
# 5439    VA         13.0                     NaN         0.749
# 5440    VA         12.3                     NaN         0.760
# 5441    VA         45.4                    0.70         0.822
# ...    ...          ...                     ...           ...
# 5698    VA         57.7                    0.83         0.479
# 5699    VA         45.2                    0.78         0.505
# 5700    VA         46.2                    0.82         0.482
# 5701    VA         11.7                    0.91         0.783
# 5702    VA         10.9                    0.91         0.785
#
#       Infant mortality  Child mortality  Children eligible for free lunch
# 5437               9.2             80.0                             0.582
# 5438               9.1            110.5                               NaN
# 5439               7.1             45.9                             0.212
# 5440               6.3             28.0                               NaN
# 5441               4.9             80.4                             0.415
# ...                ...              ...                               ...
# 5698               7.3             67.1                               NaN
# 5699               NaN             57.0                             0.390
# 5700               NaN             49.6                               NaN
# 5701               NaN             34.7                             0.129
# 5702               NaN             25.1                               NaN
#
# [266 rows x 7 columns]

# %% [markdown]
# # **Merging the Data**
#
# Now that we have both subsets to compare with, we can merge the data using the 'pd.concat' function. For this step it is important that you:
# - include the 'ignore_index=True' statement within your parenthesis
# - include the '.copy()' statement within your parenthesis to prevent the 'SettingWithoutWarning'.
#
# Your code should look somthing like this
#
#     mergeddata = pd.concat([nc_subset, va_subset], ignore_index=True).copy()

# %%
mergeddata = pd.concat([nc_subset, va_subset], ignore_index=True).copy()

# %% [markdown]
# Let's view the final subset

# %%
mergeddata
# Out:
#     State  Teen births  High school graduation  Some college  \
# 0      NC         42.4                   0.763         0.578
# 1      NC         40.3                   0.758         0.575
# 2      NC         44.2                   0.770         0.419
# 3      NC         42.1                   0.850         0.433
# 4      NC         53.8                   0.825         0.464
# ..    ...          ...                     ...           ...
# 461    VA         57.7                   0.830         0.479
# 462    VA         45.2                   0.780         0.505
# 463    VA         46.2                   0.820         0.482
# 464    VA         11.7                   0.910         0.783
# 465    VA         10.9                   0.910         0.785
#
#      Infant mortality  Child mortality  Children eligible for free lunch
# 0                 8.3             62.7                             0.444
# 1                 7.7             57.7                             0.455
# 2                 8.6             50.2                             0.417
# 3                 8.0             33.1                             0.449
# 4                 NaN              NaN                             0.523
# ..                ...              ...                               ...
# 461               7.3             67.1                               NaN
# 462               NaN             57.0                             0.390
# 463               NaN             49.6                               NaN
# 464               NaN             34.7                             0.129
# 465               NaN             25.1                               NaN
#
# [466 rows x 7 columns]

# %% [markdown]
# # **Exporting the data**#
#
# Now that we have created a new subset, we can now export the data as a .csv file using the '.to_csv' function. Your code should look like this:
#
#     mergeddata.to_csv("CountyHealthData_2014-2015.csv", index=False)
#
# **NOTE**: Make sure to specify 'index=false' so that the file won't contain the default index numnbers.

# %%
mergeddata.to_csv("CountyHealthData_2014-2015.csv", index=False)

# %% [markdown]
# That's it! Enjoy.
